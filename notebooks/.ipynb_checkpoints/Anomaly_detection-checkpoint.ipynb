# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import IsolationForest
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/processed.csv")
df['Date'] = pd.to_datetime(df['Date'])
print df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346733 entries, 0 to 346732
# Data columns (total 14 columns):
# Unnamed: 0    346733 non-null int64
# Port Name     346733 non-null object
# State         346733 non-null object
# Port Code     346733 non-null int64
# Border        346733 non-null object
# Date          346733 non-null datetime64[ns]
# Measure       346733 non-null object
# Value         346733 non-null int64
# Location      346733 non-null object
# location_x    346733 non-null float64
# location_y    346733 non-null float64
# year          346733 non-null int64
# month         346733 non-null int64
# agg_month     346733 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(5)
# memory usage: 37.0+ MB
# None

# %% [markdown]
# Some feature engineering:
# 1. generate new features: day-of-the-week and whether it's weekday
# 2. one-hot encode categorical features

# %%
df['day_of_the_week'] = df['Date'].dt.dayofweek
df['is_week_day'] = (df['day_of_the_week'] < 5).astype(int)

def transfer_column(df_input):
    num_features = ['agg_month', 'day_of_the_week', 'Value', 'year', 'month']
    ctg_features = ['Port Name', 'State', 'Border', 'Measure', 'is_week_day']
    num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="median")),
        ('std_scaler', StandardScaler()),
    ])
    full_pipeline = ColumnTransformer([
        ("num", num_pipeline, num_features),
        ("cat", OneHotEncoder(), ctg_features)
    ])
    np_pipelined = full_pipeline.fit_transform(df_input)
    import scipy
    if isinstance(np_pipelined, scipy.sparse.csr.csr_matrix):
        np_pipelined = np_pipelined.toarray()
    df_pipelined = pd.DataFrame(np_pipelined, index=df_input.index)
    return df_pipelined

# %% [markdown]
# Training isolation forest on California cross border entry data

# %%
df_partial = df[(df['State'] == 'California')]

# %%
def train_isolation_forest(df_input, outliers_fraction=0.05):
    df_input_pipelined = transfer_column(df_input)
    df_input_pipelined = pd.DataFrame(df_input_pipelined)
    outliers_fraction = 0.05
    IF_model = IsolationForest(contamination=outliers_fraction)
    IF_model.fit(df_input_pipelined)
    print "Isolation forest trained, making predictions..."
    df_input_pipelined['anomaly_by_if'] = pd.Series(IF_model.predict(df_input_pipelined))
    df_input_pipelined['anomaly_by_if'] = df_input_pipelined['anomaly_by_if'].map( {1: 0, -1: 1} )
    return df_input_pipelined

def plot_anomaly_using_tsne(df_input):
    from sklearn.manifold import TSNE
    df_input_pipelined = transfer_column(df_input)
    if df_input_pipelined.shape[1] == 1:
        df_input_pipelined = df_input_pipelined
    tsne_model = TSNE(n_components=2, perplexity=50, learning_rate=100, n_iter=2000, verbose=0, random_state=0, angle=0.75)
    tsne_vectors = tsne_model.fit_transform(df_input_pipelined)
    df_input_pipelined = train_isolation_forest(df_input)
    anomalies_indices = df_input_pipelined[df_input_pipelined['anomaly_by_if'] == 1].index
    tsne_vectors_anomaly = [v for idx, v in enumerate(tsne_vectors) if idx in anomalies_indices]
    fig, ax = plt.subplots(figsize=(10, 10))
    COLOR_MAP = np.array(["#9edae6"])
    plt.scatter(x=tsne_vectors[:, 0], y=tsne_vectors[:, 1], color=COLOR_MAP, marker='o', alpha=0.5)
    plt.scatter(x=[v[0] for v in tsne_vectors_anomaly], y=[v[1] for v in tsne_vectors_anomaly], color='red', marker='o', alpha=0.5)
    plt.show()
    
plot_anomaly_using_tsne(df_partial)
# Out:
# Isolation forest trained, making predictions...
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/ensemble/iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)

# %% [markdown]
# Anomaly samples deep dive

# %%
df_input_pipelined = train_isolation_forest(df_partial)
anomalies_indices = df_input_pipelined[df_input_pipelined['anomaly_by_if'] == 1].index
df_anomaly = df_partial[df_partial.index.isin(anomalies_indices)]
df_anomaly.to_csv("../data/processed/anomalies_CA.csv")
df_anomaly.head()
# Out:
# Isolation forest trained, making predictions...
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/ensemble/iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
#      Unnamed: 0      Port Name       State  Port Code            Border  \
# 94           94      Otay Mesa  California       2506  US-Mexico Border
# 152         152  Calexico East  California       2507  US-Mexico Border
# 236         236     San Ysidro  California       2504  US-Mexico Border
# 459         459      Otay Mesa  California       2506  US-Mexico Border
# 707         707         Tecate  California       2505  US-Mexico Border
#
#           Date                      Measure    Value  \
# 94  2019-03-01        Truck Containers Full    63197
# 152 2019-03-01             Train Passengers       21
# 236 2019-03-01  Personal Vehicle Passengers  2045733
# 459 2019-03-01                       Trains       38
# 707 2019-03-01                       Trucks     4608
#
#                                  Location  location_x  location_y  year  \
# 94            POINT (-117.05333 32.57333)  -117.05333    32.57333  2019
# 152  POINT (-115.48433000000001 32.67524)  -115.48433    32.67524  2019
# 236  POINT (-117.02666999999998 32.54306)  -117.02667    32.54306  2019
# 459           POINT (-117.05333 32.57333)  -117.05333    32.57333  2019
# 707           POINT (-116.62667 32.57722)  -116.62667    32.57722  2019
#
#      month  agg_month  day_of_the_week  is_week_day
# 94       3        279                4            1
# 152      3        279                4            1
# 236      3        279                4            1
# 459      3        279                4            1
# 707      3        279                4            1

# %%
def plot_anomalies_breakdown(df_anomaly):
    from itertools import islice
    sorted_uniques = df_anomaly.groupby(['Port Name', 'Measure']).size().sort_values(ascending=False)
    print list(islice(sorted_uniques.iteritems(), 7))
    for i in range(3):
        port_name, measure = list(islice(sorted_uniques.iteritems(), 3))[i][0]
        df_anml_condition = df[(df['Port Name'] == port_name) & (df['Measure'] == measure)]
        anml_sample_indices = df_anomaly[(df_anomaly['Port Name'] == port_name) & (df['Measure'] == measure)].index.to_list()

        plt.figure(figsize=(12, 5), dpi=100)
        plt.title("Anomalies in subset (port: {}, measure: {})".format(port_name, measure))
        plt.plot(df_anml_condition['Date'], df_anml_condition['Value'])
        for index in anml_sample_indices:
            plt.scatter(df_anml_condition.loc[index, :]['Date'], df_anml_condition.loc[index, :]['Value'], color='red')
plot_anomalies_breakdown(df_anomaly)
# Out:
# [(('San Ysidro', 'Buses'), 6), (('Tecate', 'Trucks'), 4), (('Otay Mesa', 'Trains'), 4), (('Calexico', 'Pedestrians'), 3), (('Calexico', 'Personal Vehicle Passengers'), 3), (('Tecate', 'Truck Containers Full'), 3), (('Andrade', 'Personal Vehicles'), 2)]

# %%
df_us_mx = df[(df['Border'] == 'US-Mexico Border')]
print len(df_us_mx.index)
plot_anomaly_using_tsne(df_us_mx)
# Out:
# 80546

# %%
df_input_pipelined = train_isolation_forest(df_truck)
anomalies_indices = df_input_pipelined[df_input_pipelined['anomaly_by_if'] == 1].index
df_anomaly = df_partial[df_partial.index.isin(anomalies_indices)]
df_anomaly.to_csv("../data/processed/anomalies_truck.csv")
plot_anomalies_breakdown(df_anomaly)
# Out:
# Isolation forest trained, making predictions...
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/ensemble/iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
#        Unnamed: 0      Port Name       State  Port Code            Border  \
# 2804         2804  Calexico East  California       2507  US-Mexico Border
# 5077         5077  Calexico East  California       2507  US-Mexico Border
# 27238       27238       Calexico  California       2503  US-Mexico Border
# 28650       28650     San Ysidro  California       2504  US-Mexico Border
#
#             Date Measure  Value                              Location  \
# 2804  2018-12-01  Trucks  29704  POINT (-115.48433000000001 32.67524)
# 5077  2018-09-01  Trucks  29426  POINT (-115.48433000000001 32.67524)
# 27238 2016-07-01  Trucks      0     POINT (-115.49999999999999 32.66)
# 28650 2016-06-01  Trucks      0                 POINT (-117.03 32.54)
#
#        location_x  location_y  year  month  agg_month  day_of_the_week  \
# 2804   -115.48433    32.67524  2018     12        276                5
# 5077   -115.48433    32.67524  2018      9        273                5
# 27238  -115.50000    32.66000  2016      7        247                4
# 28650  -117.03000    32.54000  2016      6        246                2
#
#        is_week_day
# 2804             0
# 5077             0
# 27238            1
# 28650            1
